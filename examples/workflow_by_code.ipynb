# %% [markdown]
# <a href="https://colab.research.google.com/github/microsoft/qlib/blob/main/examples/workflow_by_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#  Copyright (c) Microsoft Corporation.
#  Licensed under the MIT License.

# %%
import sys, site
from pathlib import Path

################################# NOTE #################################
#  Please be aware that if colab installs the latest numpy and pyqlib  #
#  in this cell, users should RESTART the runtime in order to run the  #
#  following cells successfully.                                       #
########################################################################

try:
    import qlib
except ImportError:
    # install qlib
    ! pip install --upgrade numpy
    ! pip install pyqlib
    if "google.colab" in sys.modules:
        # The Google colab environment is a little outdated. We have to downgrade the pyyaml to make it compatible with other packages
        ! pip install pyyaml==5.4.1
    # reload
    site.main()

scripts_dir = Path.cwd().parent.joinpath("scripts")
if not scripts_dir.joinpath("get_data.py").exists():
    # download get_data.py script
    scripts_dir = Path("~/tmp/qlib_code/scripts").expanduser().resolve()
    scripts_dir.mkdir(parents=True, exist_ok=True)
    import requests

    with requests.get("https://raw.githubusercontent.com/microsoft/qlib/main/scripts/get_data.py", timeout=10) as resp:
        with open(scripts_dir.joinpath("get_data.py"), "wb") as fp:
            fp.write(resp.content)

# %%
import qlib
import pandas as pd
from qlib.constant import REG_CN
from qlib.utils import exists_qlib_data, init_instance_by_config
from qlib.workflow import R
from qlib.workflow.record_temp import SignalRecord, PortAnaRecord
from qlib.utils import flatten_dict

# %%
# use default data
# NOTE: need to download data from remote: python scripts/get_data.py qlib_data_cn --target_dir ~/.qlib/qlib_data/cn_data
provider_uri = "~/.qlib/qlib_data/cn_data"  # target_dir
if not exists_qlib_data(provider_uri):
    print(f"Qlib data is not found in {provider_uri}")
    sys.path.append(str(scripts_dir))
    from get_data import GetData

    GetData().qlib_data(target_dir=provider_uri, region=REG_CN)
qlib.init(provider_uri=provider_uri, region=REG_CN)
# Out:
# [2827773:MainThread](2025-11-11 15:01:22,265) INFO - qlib.Initialization - [config.py:452] - default_conf: client.
# [2827773:MainThread](2025-11-11 15:01:22,269) INFO - qlib.Initialization - [__init__.py:75] - qlib successfully initialized based on client settings.
# [2827773:MainThread](2025-11-11 15:01:22,271) INFO - qlib.Initialization - [__init__.py:77] - data_path={'__DEFAULT_FREQ': PosixPath('/home/tang20/.qlib/qlib_data/cn_data')}

# %%
market = "csi300"
benchmark = "SH000300"

# %% [markdown]
# # train model

# %%
###################################
# train model
###################################
data_handler_config = {
    "start_time": "2008-01-01",
    "end_time": "2025-11-01",
    "fit_start_time": "2008-01-01",
    "fit_end_time": "2025-01-11",
    "instruments": market,
}

task = {
    "model": {
        "class": "LGBModel",
        "module_path": "qlib.contrib.model.gbdt",
        "kwargs": {
            "loss": "mse",
            "colsample_bytree": 0.8879,
            "learning_rate": 0.0421,
            "subsample": 0.8789,
            "lambda_l1": 205.6999,
            "lambda_l2": 580.9768,
            "max_depth": 8,
            "num_leaves": 210,
            "num_threads": 20,
        },
    },
    "dataset": {
        "class": "DatasetH",
        "module_path": "qlib.data.dataset",
        "kwargs": {
            "handler": {
                "class": "Alpha158",
                "module_path": "qlib.contrib.data.handler",
                "kwargs": data_handler_config,
            },
            "segments": {
                "train": ("2008-01-01", "2018-12-31"),
                "valid": ("2018-01-01", "2019-12-31"),
                "test": ("2020-01-01", "2025-11-01"),
            },
        },
    },
}

# model initialization
model = init_instance_by_config(task["model"])
dataset = init_instance_by_config(task["dataset"])

# start exp to train model
with R.start(experiment_name="train_model"):
    R.log_params(**flatten_dict(task))
    model.fit(dataset)
    R.save_objects(trained_model=model)
    rid = R.get_recorder().id

# %% [markdown]
# # prediction, backtest & analysis

# %%
###################################
# prediction, backtest & analysis
###################################
port_analysis_config = {
    "executor": {
        "class": "SimulatorExecutor",
        "module_path": "qlib.backtest.executor",
        "kwargs": {
            "time_per_step": "day",
            "generate_portfolio_metrics": True,
        },
    },
    "strategy": {
        "class": "TopkDropoutStrategy",
        "module_path": "qlib.contrib.strategy.signal_strategy",
        "kwargs": {
            "model": model,
            "dataset": dataset,
            "topk": 50,
            "n_drop": 5,
        },
    },
    "backtest": {
        "start_time": "2017-01-01",
        "end_time": "2020-08-01",
        "account": 100000000,
        "benchmark": benchmark,
        "exchange_kwargs": {
            "freq": "day",
            "limit_threshold": 0.095,
            "deal_price": "close",
            "open_cost": 0.0005,
            "close_cost": 0.0015,
            "min_cost": 5,
        },
    },
}

# backtest and analysis
with R.start(experiment_name="backtest_analysis"):
    recorder = R.get_recorder(recorder_id=rid, experiment_name="train_model")
    model = recorder.load_object("trained_model")

    # prediction
    recorder = R.get_recorder()
    ba_rid = recorder.id
    sr = SignalRecord(model, dataset, recorder)
    sr.generate()

    # backtest & analysis
    par = PortAnaRecord(recorder, port_analysis_config, "day")
    par.generate()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[9], line 40
#       4 port_analysis_config = {
#       5     "executor": {
#       6         "class": "SimulatorExecutor",
#    (...)
#      36     },
#      37 }
#      39 # backtest and analysis
# ---> 40 with R.start(experiment_name="backtest_analysis"):
#      41     recorder = R.get_recorder(recorder_id=rid, experiment_name="train_model")
#      42     model = recorder.load_object("trained_model")
#
# File ~/anaconda3/envs/qlib_py39/lib/python3.9/contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     117 del self.args, self.kwds, self.func
#     118 try:
# --> 119     return next(self.gen)
#     120 except StopIteration:
#     121     raise RuntimeError("generator didn't yield") from None
#
# File ~/anaconda3/envs/qlib_py39/lib/python3.9/site-packages/qlib/workflow/__init__.py:82, in QlibRecorder.start(self, experiment_id, experiment_name, recorder_id, recorder_name, uri, resume)
#      37 @contextmanager
#      38 def start(
#      39     self,
#    (...)
#      46     resume: bool = False,
#      47 ):
#      48     """
#      49     Method to start an experiment. This method can only be called within a Python's `with` statement. Here is the example code:
#      50
#    (...)
#      80         whether to resume the specific recorder with given name under the given experiment.
#      81     """
# ---> 82     run = self.start_exp(
#      83         experiment_id=experiment_id,
#      84         experiment_name=experiment_name,
#      85         recorder_id=recorder_id,
#      86         recorder_name=recorder_name,
#      87         uri=uri,
#      88         resume=resume,
#      89     )
#      90     try:
#      91         yield run
#
# File ~/anaconda3/envs/qlib_py39/lib/python3.9/site-packages/qlib/workflow/__init__.py:138, in QlibRecorder.start_exp(self, experiment_id, experiment_name, recorder_id, recorder_name, uri, resume)
#      97 def start_exp(
#      98     self,
#      99     *,
#    (...)
#     105     resume=False,
#     106 ):
#     107     """
#     108     Lower level method for starting an experiment. When use this method, one should end the experiment manually
#     109     and the status of the recorder may not be handled properly. Here is the example code:
#    (...)
#     136     An experiment instance being started.
#     137     """
# --> 138     return self.exp_manager.start_exp(
#     139         experiment_id=experiment_id,
#     140         experiment_name=experiment_name,
#     141         recorder_id=recorder_id,
#     142         recorder_name=recorder_name,
#     143         uri=uri,
#     144         resume=resume,
#     145     )
#
# File ~/anaconda3/envs/qlib_py39/lib/python3.9/site-packages/qlib/workflow/expm.py:86, in ExpManager.start_exp(self, experiment_id, experiment_name, recorder_id, recorder_name, uri, resume, **kwargs)
#      83 self._active_exp_uri = uri
#      84 # The subclass may set the underlying uri back.
#      85 # So setting `_active_exp_uri` come before `_start_exp`
# ---> 86 return self._start_exp(
#      87     experiment_id=experiment_id,
#      88     experiment_name=experiment_name,
#      89     recorder_id=recorder_id,
#      90     recorder_name=recorder_name,
#      91     resume=resume,
#      92     **kwargs,
#      93 )
#
# File ~/anaconda3/envs/qlib_py39/lib/python3.9/site-packages/qlib/workflow/expm.py:341, in MLflowExpManager._start_exp(self, experiment_id, experiment_name, recorder_id, recorder_name, resume)
#     339 if experiment_name is None:
#     340     experiment_name = self._default_exp_name
# --> 341 experiment, _ = self._get_or_create_exp(experiment_id=experiment_id, experiment_name=experiment_name)
#     342 # Set up active experiment
#     343 self.active_experiment = experiment
#
# File ~/anaconda3/envs/qlib_py39/lib/python3.9/site-packages/qlib/workflow/expm.py:225, in ExpManager._get_or_create_exp(self, experiment_id, experiment_name)
#     219 """
#     220 Method for getting or creating an experiment. It will try to first get a valid experiment, if exception occurs, it will
#     221 automatically create a new experiment based on the given id and name.
#     222 """
#     223 try:
#     224     return (
# --> 225         self._get_exp(experiment_id=experiment_id, experiment_name=experiment_name),
#     226         False,
#     227     )
#     228 except ValueError:
#     229     if experiment_name is None:
#
# File ~/anaconda3/envs/qlib_py39/lib/python3.9/site-packages/qlib/workflow/expm.py:389, in MLflowExpManager._get_exp(self, experiment_id, experiment_name)
#     387 elif experiment_name is not None:
#     388     try:
# --> 389         exp = self.client.get_experiment_by_name(experiment_name)
#     390         if exp is None or exp.lifecycle_stage.upper() == "DELETED":
#     391             raise MlflowException("No valid experiment has been found.")
#
# File ~/anaconda3/envs/qlib_py39/lib/python3.9/site-packages/mlflow/tracking/client.py:1747, in MlflowClient.get_experiment_by_name(self, name)
#    1715 def get_experiment_by_name(self, name: str) -> Optional[Experiment]:
#    1716     """Retrieve an experiment by experiment name from the backend store
#    1717
#    1718     Args:
#    (...)
#    1745         Lifecycle_stage: active
#    1746     """
# -> 1747     return self._tracking_client.get_experiment_by_name(name)
#
# File ~/anaconda3/envs/qlib_py39/lib/python3.9/site-packages/mlflow/tracking/_tracking_service/client.py:258, in TrackingServiceClient.get_experiment_by_name(self, name)
#     250 def get_experiment_by_name(self, name):
#     251     """
#     252     Args:
#     253         name: The experiment name.
#    (...)
#     256         :py:class:`mlflow.entities.Experiment`
#     257     """
# --> 258     return self.store.get_experiment_by_name(name)
#
# File ~/anaconda3/envs/qlib_py39/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py:382, in FileStore.get_experiment_by_name(self, experiment_name)
#     374 def pagination_wrapper_func(number_to_get, next_page_token):
#     375     return self.search_experiments(
#     376         view_type=ViewType.ALL,
#     377         max_results=number_to_get,
#     378         filter_string=f"name = '{experiment_name}'",
#     379         page_token=next_page_token,
#     380     )
# --> 382 experiments = get_results_from_paginated_fn(
#     383     paginated_fn=pagination_wrapper_func,
#     384     max_results_per_page=SEARCH_MAX_RESULTS_THRESHOLD,
#     385     max_results=None,
#     386 )
#     387 return experiments[0] if len(experiments) > 0 else None
#
# File ~/anaconda3/envs/qlib_py39/lib/python3.9/site-packages/mlflow/utils/__init__.py:238, in get_results_from_paginated_fn(paginated_fn, max_results_per_page, max_results)
#     236     page_results = paginated_fn(num_to_get, next_page_token)
#     237 else:
# --> 238     page_results = paginated_fn(max_results_per_page, next_page_token)
#     239 all_results.extend(page_results)
#     240 if hasattr(page_results, "token") and page_results.token:
#
# File ~/anaconda3/envs/qlib_py39/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py:375, in FileStore.get_experiment_by_name.<locals>.pagination_wrapper_func(number_to_get, next_page_token)
#     374 def pagination_wrapper_func(number_to_get, next_page_token):
# --> 375     return self.search_experiments(
#     376         view_type=ViewType.ALL,
#     377         max_results=number_to_get,
#     378         filter_string=f"name = '{experiment_name}'",
#     379         page_token=next_page_token,
#     380     )
#
# File ~/anaconda3/envs/qlib_py39/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py:345, in FileStore.search_experiments(self, view_type, max_results, filter_string, order_by, page_token)
#     338 if max_results > SEARCH_MAX_RESULTS_THRESHOLD:
#     339     raise MlflowException(
#     340         f"Invalid value {max_results} for parameter 'max_results' supplied. It must be at "
#     341         f"most {SEARCH_MAX_RESULTS_THRESHOLD}",
#     342         INVALID_PARAMETER_VALUE,
#     343     )
# --> 345 self._check_root_dir()
#     346 experiment_ids = []
#     347 if view_type == ViewType.ACTIVE_ONLY or view_type == ViewType.ALL:
#
# File ~/anaconda3/envs/qlib_py39/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py:233, in FileStore._check_root_dir(self)
#     229 """
#     230 Run checks before running directory operations.
#     231 """
#     232 if not exists(self.root_directory):
# --> 233     raise Exception(f"'{self.root_directory}' does not exist.")
#     234 if not is_directory(self.root_directory):
#     235     raise Exception(f"'{self.root_directory}' is not a directory.")
#
# Exception: '/home/tang20/Programs/Codes/QuantitativeTrading/qlib/examples/mlruns' does not exist.

# %% [markdown]
# # analyze graphs

# %%
from qlib.contrib.report import analysis_model, analysis_position
from qlib.data import D

recorder = R.get_recorder(recorder_id=ba_rid, experiment_name="backtest_analysis")
print(recorder)
pred_df = recorder.load_object("pred.pkl")
report_normal_df = recorder.load_object("portfolio_analysis/report_normal_1day.pkl")
positions = recorder.load_object("portfolio_analysis/positions_normal_1day.pkl")
analysis_df = recorder.load_object("portfolio_analysis/port_analysis_1day.pkl")

# %% [markdown]
# ## analysis position

# %% [markdown]
# ### report

# %%
analysis_position.report_graph(report_normal_df)

# %% [markdown]
# ### risk analysis

# %%
analysis_position.risk_analysis_graph(analysis_df, report_normal_df)

# %% [markdown]
# ## analysis model

# %%
label_df = dataset.prepare("test", col_set="label")
label_df.columns = ["label"]

# %% [markdown]
# ### score IC

# %%
pred_label = pd.concat([label_df, pred_df], axis=1, sort=True).reindex(label_df.index)
analysis_position.score_ic_graph(pred_label)

# %% [markdown]
# ### model performance

# %%
analysis_model.model_performance_graph(pred_label)
